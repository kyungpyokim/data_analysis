# %% [markdown]
# # 1. 넘파이 불러오기

# %% [markdown]
# # 2. 배열 생성

# %% [markdown]
# ## 1) 차원별 배열 생성

# %% [markdown]
# ## 2) 패턴이 있는 배열 생성

# %% [markdown]
# ## 3) 난수 배열 생성

# %% [markdown]
# # 3. 배열 속성

# %% [markdown]
# # 4. 배열 변환

# %% [markdown]
# # 5. 배열 연산

# %% [markdown]
# # 6. 이미지 데이터
